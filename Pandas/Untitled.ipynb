# %%
import numpy as np
import pandas as pd

# %%
dist = {
    "name" : ['Aditya','Rohan','Sachin','Sankalp'],
     "age" : [20,23,24,25],
    "CGPA" : [9.22,7.9,8.99,9.31]
}

# %%
df = pd.DataFrame(dist)

# %%
df
# Out:
#       name  age  CGPA
# 0   Aditya   20  9.22
# 1    Rohan   23  7.90
# 2   Sachin   24  8.99
# 3  Sankalp   25  9.31

# %%
df.to_csv('Data.csv')

# %%
df.to_csv('Data_Without_Index.csv', index = False)

# %%
df.head(2)
# Out:
#      name  age  CGPA
# 0  Aditya   20  9.22
# 1   Rohan   23  7.90

# %%
df.tail(2)
# Out:
#       name  age  CGPA
# 2   Sachin   24  8.99
# 3  Sankalp   25  9.31

# %%
df.describe( )
# Out:
#              age      CGPA
# count   4.000000  4.000000
# mean   23.000000  8.855000
# std     2.160247  0.650769
# min    20.000000  7.900000
# 25%    22.250000  8.717500
# 50%    23.500000  9.105000
# 75%    24.250000  9.242500
# max    25.000000  9.310000

# %%
New_Data = pd.read_csv('New_Data.csv')

# %%
New_Data
# Out:
#    Train No. Name Location
# 0        123    A        X
# 1        124    B        Y
# 2        125    C        Z
# 3        127    D        W

# %%
New_Data['Name']
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# Name: Name, dtype: str

# %%
New_Data['Name'][0]
# Out:
# 'A'

# %%
New_Data['Name'][0] = 'B'
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_20464\3600245388.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   New_Data['Name'][0] = 'B'

# %%
New_Data['Name'][0]
# Out:
# 'A'

# %%
New_Data.index = ['f','s','t','f']

# %%
New_Data
# Out:
#    Train No. Name Location
# f        123    A        X
# s        124    B        Y
# t        125    C        Z
# f        127    D        W

# %%
import pandas as pd 
newdf = pd.DataFrame({
    "Name" : ['Aditya' , 'Sachin',2]})

# %%
newdf.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
newdf.columns
# Out:
# Index(['Name'], dtype='str')

# %%
newdf.dtypes
# Out:
# Name    object
# dtype: object
